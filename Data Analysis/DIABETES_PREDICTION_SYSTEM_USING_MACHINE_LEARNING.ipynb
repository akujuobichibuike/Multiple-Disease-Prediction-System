# %% [markdown]
# # **DIABETES PREDICTION SYSTEM USING MACHINE LEARNING**
#
# In this project, I will be predicting that whether a patient has diabetes or not on the basis of the features I will provide to the machine learning model, and for that, we will be using the famous PIMA Indians Diabetes Database.

# %% [markdown]
# Importing the Dependencies.

# %%
import numpy as np
import pandas as pd
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import pickle

sns.set()

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from mlxtend.plotting import plot_decision_regions
from xgboost import XGBClassifier
from pandas.plotting import scatter_matrix

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Data Collection & Analysis.
#
# About the Dataset
#
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. The dataset consists of several medical predictor variables and one target variable, **Outcome**. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %% [markdown]
# Importing the Dataset.

# %%
# loading the diabetes dataset to a pandas dataframe for easier analysis

diabetes_dataset = pd.read_csv('/content/diabetes.csv')

# %%
# printing the first 5 rows of the dataset

diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
# number of rows and columns in the dataset

diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# getting the statistical measures of the data

diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# 0 = Non Diabetic
#
# 1 = Diabetic

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# checking if the dataset has null values

diabetes_dataset.isnull().head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False          False    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
# 5        False    False          False          False    False  False
# 6        False    False          False          False    False  False
# 7        False    False          False          False    False  False
# 8        False    False          False          False    False  False
# 9        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False
# 5                     False  False    False
# 6                     False  False    False
# 7                     False  False    False
# 8                     False  False    False
# 9                     False  False    False

# %%
diabetes_dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_dataset_copy = diabetes_dataset.copy(deep = True)
diabetes_dataset_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = diabetes_dataset_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# Showing the Count of NANs
print(diabetes_dataset_copy.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# **Data Visualization**
#
# Plotting the data distribution before removing null values.

# %%
p = diabetes_dataset.hist(figsize = (20,20))

# %% [markdown]
# So here we have seen the distribution of each features whether it is dependent data or independent data and one thing which could always strike that why do we need to see the distribution of data? So the answer is simple it is the best way to start the analysis of the dataset as it shows the occurrence of every kind of value in the graphical structure which in turn lets us know the range of the data.
#
# Now we will be imputing the mean value of the column to each missing value of that particular column.

# %%
diabetes_dataset_copy['Glucose'].fillna(diabetes_dataset_copy['Glucose'].mean(), inplace = True)
diabetes_dataset_copy['BloodPressure'].fillna(diabetes_dataset_copy['BloodPressure'].mean(), inplace = True)
diabetes_dataset_copy['SkinThickness'].fillna(diabetes_dataset_copy['SkinThickness'].median(), inplace = True)
diabetes_dataset_copy['Insulin'].fillna(diabetes_dataset_copy['Insulin'].median(), inplace = True)
diabetes_dataset_copy['BMI'].fillna(diabetes_dataset_copy['BMI'].median(), inplace = True)

# %% [markdown]
# Plotting the distribuitions after removing the NAN values.

# %%
p = diabetes_dataset_copy.hist(figsize = (20,20))

# %% [markdown]
# Here we are again using the hist plot to see the distribution of the dataset but this time we are using this visualization to see the changes that we can see after those null values are removed from the dataset and we can clearly see the difference for example – In age column after removal of the null values, we can see that there is a spike at the range of 50 to 100 which is quite logical as well.

# %% [markdown]
# Plotting Null Count Analysis Plot.

# %%
p = msno.bar(diabetes_dataset)

# %% [markdown]
# Now in the above graph also we can clearly see that there are no null values in the dataset.

# %% [markdown]
# Now, let’s check that how well the outcome column is balanced

# %%
color_wheel = {1: "#0392cf", 2: "#7bc043"}
colors = diabetes_dataset["Outcome"].map(lambda x: color_wheel.get(x + 1))
print(diabetes_dataset.Outcome.value_counts())
p=diabetes_dataset.Outcome.value_counts().plot(kind="bar")
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# from the above visualization it is clearly visible that our dataset is completely imbalanced in fact the number of patients who are diabetic is half of the patients who are non-diabetic.

# %% [markdown]
# **Correlation between all the features.**
#
# Correlation between all the features before cleaning

# %%
plt.figure(figsize=(12,10))
# seaborn has an easy method to showcase heatmap
p = sns.heatmap(diabetes_dataset.corr(), annot=True,cmap ='RdYlGn')

# %% [markdown]
# **Scaling the Data**

# %%
diabetes_dataset_copy.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# After Standard Scaling:

# %%
sc_X = StandardScaler()
X =  pd.DataFrame(sc_X.fit_transform(diabetes_dataset_copy.drop(["Outcome"],axis = 1),), columns=['Pregnancies',
'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'])

X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.865108      -0.033518       0.670643 -0.181541  0.166619
# 1    -0.844885 -1.206162      -0.529859      -0.012301 -0.181541 -0.852200
# 2     1.233880  2.015813      -0.695306      -0.012301 -0.181541 -1.332500
# 3    -0.844885 -1.074652      -0.529859      -0.695245 -0.540642 -0.633881
# 4    -1.141852  0.503458      -2.680669       0.670643  0.316566  1.549303
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %% [markdown]
# **Building the Model**
#
# Splitting the dataset:

# %%
X = diabetes_dataset.drop('Outcome', axis = 1)
y = diabetes_dataset['Outcome']

# %% [markdown]
# Now we will split the data into training and testing data using the train_test_split function

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, stratify=y, random_state=4)

# %% [markdown]
# **SVM**
#
# Building the model using SVM

# %%
classifier = svm.SVC(kernel = 'linear', probability=True)

# %%
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %% [markdown]
# Now after building the model let's check the accuracy of the model on the training dataset and calculate the accuracy score.

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print('Accuracy score on the training data : ', training_data_accuracy)
# Out:
# Accuracy score on the training data :  0.7850162866449512

# %%
# accuracy score on the test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print('Accuracy score on the test data : ', test_data_accuracy)
# Out:
# Accuracy score on the test data :  0.7207792207792207

# %% [markdown]
# Classification report and confusion matrix of the SVM classifier

# %%
print(confusion_matrix(y_test, X_test_prediction))
print(classification_report(y_test, X_test_prediction))
# Out:
# [[78 22]
#  [21 33]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       100
#            1       0.60      0.61      0.61        54
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.70      0.69       154
# weighted avg       0.72      0.72      0.72       154

# %% [markdown]
# **Random Forest**
#
# Building the model using RandomForest

# %%
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %% [markdown]
# Now after building the model let’s check the accuracy of the model on the training dataset.

# %%
# accuracy score on training data
rfc_train = rfc.predict(X_train)
print("Accuracy_Score =", format(metrics.accuracy_score(y_train, rfc_train)))
# Out:
# Accuracy_Score = 1.0

# %% [markdown]
# So here we can see that on the training dataset our model is overfitted.

# %%
# accuracy score on test data
predictions = rfc.predict(X_test)
print("Accuracy_Score =", format(metrics.accuracy_score(y_test, predictions)))
# Out:
# Accuracy_Score = 0.7012987012987013

# %% [markdown]
# Classification report and confusion matrix of the random forest model

# %%
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[73 27]
#  [19 35]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76       100
#            1       0.56      0.65      0.60        54
#
#     accuracy                           0.70       154
#    macro avg       0.68      0.69      0.68       154
# weighted avg       0.71      0.70      0.71       154

# %% [markdown]
# **Decision Tree**
#
# Building the model using DecisionTree

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# accuracy score on training data
predictions = dtree.predict(X_train)
print("Accuracy Score =", format(metrics.accuracy_score(y_train,predictions)))
# Out:
# Accuracy Score = 1.0

# %%
# accuracy score on test data
predictions = dtree.predict(X_test)
print("Accuracy Score =", format(metrics.accuracy_score(y_test,predictions)))
# Out:
# Accuracy Score = 0.6558441558441559

# %% [markdown]
# Classification report and confusion matrix of the decision tree model

# %%
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test,predictions))
# Out:
# [[70 30]
#  [23 31]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73       100
#            1       0.51      0.57      0.54        54
#
#     accuracy                           0.66       154
#    macro avg       0.63      0.64      0.63       154
# weighted avg       0.67      0.66      0.66       154

# %% [markdown]
# **XgBoost Classifier**
#
# Building the model using XGBoost

# %%
xgb_model = XGBClassifier(gamma=0)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
# accuracy on test data
xgb_pred = xgb_model.predict(X_test)
print("Accuracy Score =", format(metrics.accuracy_score(y_test, xgb_pred)))
# Out:
# Accuracy Score = 0.6818181818181818

# %% [markdown]
# Classification report and confusion matrix of the XgBoost classifier

# %%
print(confusion_matrix(y_test, xgb_pred))
print(classification_report(y_test, xgb_pred))
# Out:
# [[71 29]
#  [20 34]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.74       100
#            1       0.54      0.63      0.58        54
#
#     accuracy                           0.68       154
#    macro avg       0.66      0.67      0.66       154
# weighted avg       0.70      0.68      0.69       154

# %% [markdown]
# **The Conclusion from Model Building**
#
# Therefore SVM is the best model for this prediction since it has an accuracy_score of 0.74.

# %% [markdown]
# **Saving the SVM Model**
#
# Saving the model using pickle

# %%
# Firstly we will be using the dump() function to save the model using pickle
saved_model = pickle.dumps(classifier)

# %%
# Serialize the model and save it to a file
with open('diabetes_model.sav', 'wb') as model_file:
    model_file.write(saved_model)

# %%
# Then we will be loading that saved model
classifier_from_pickle = pickle.loads(saved_model)

# %%
# lastly, after loading that model we will use this to make predictions
classifier_from_pickle.predict_proba(X_test)
# Out:
# array([[0.81631888, 0.18368112],
#        [0.09061595, 0.90938405],
#        [0.78793277, 0.21206723],
#        [0.3837338 , 0.6162662 ],
#        [0.41888235, 0.58111765],
#        [0.60039751, 0.39960249],
#        [0.75202316, 0.24797684],
#        [0.88586432, 0.11413568],
#        [0.80726507, 0.19273493],
#        [0.6127267 , 0.3872733 ],
#        [0.20819391, 0.79180609],
#        [0.3931625 , 0.6068375 ],
#        [0.21650725, 0.78349275],
#        [0.78372672, 0.21627328],
#        [0.79996905, 0.20003095],
#        [0.2928165 , 0.7071835 ],
#        [0.71849163, 0.28150837],
#        [0.11813656, 0.88186344],
#        [0.53086492, 0.46913508],
#        [0.59075479, 0.40924521],
#        [0.71076097, 0.28923903],
#        [0.76127765, 0.23872235],
#        [0.71521883, 0.28478117],
#        [0.81342173, 0.18657827],
#        [0.08816701, 0.91183299],
#        [0.5612694 , 0.4387306 ],
#        [0.20505431, 0.79494569],
#        [0.69504184, 0.30495816],
#        [0.46118668, 0.53881332],
#        [0.18520711, 0.81479289],
#        [0.71546073, 0.28453927],
#        [0.55718025, 0.44281975],
#        [0.91497607, 0.08502393],
#        [0.66109049, 0.33890951],
#        [0.62441638, 0.37558362],
#        [0.88578859, 0.11421141],
#        [0.24229821, 0.75770179],
#        [0.53109981, 0.46890019],
#        [0.93329564, 0.06670436],
#        [0.46120909, 0.53879091],
#        [0.45037039, 0.54962961],
#        [0.34425842, 0.65574158],
#        [0.43796013, 0.56203987],
#        [0.20960887, 0.79039113],
#        [0.32809307, 0.67190693],
#        [0.38573444, 0.61426556],
#        [0.73279459, 0.26720541],
#        [0.91761393, 0.08238607],
#        [0.72708651, 0.27291349],
#        [0.85268696, 0.14731304],
#        [0.83476234, 0.16523766],
#        [0.59124153, 0.40875847],
#        [0.69219014, 0.30780986],
#        [0.81730552, 0.18269448],
#        [0.95667962, 0.04332038],
#        [0.75430717, 0.24569283],
#        [0.47120298, 0.52879702],
#        [0.20006171, 0.79993829],
#        [0.73520006, 0.26479994],
#        [0.27082337, 0.72917663],
#        [0.11750934, 0.88249066],
#        [0.86308433, 0.13691567],
#        [0.6915888 , 0.3084112 ],
#        [0.19085098, 0.80914902],
#        [0.87051049, 0.12948951],
#        [0.75700991, 0.24299009],
#        [0.29336699, 0.70663301],
#        [0.46633732, 0.53366268],
#        [0.78148872, 0.21851128],
#        [0.63592991, 0.36407009],
#        [0.5286934 , 0.4713066 ],
#        [0.38764098, 0.61235902],
#        [0.94871049, 0.05128951],
#        [0.32139113, 0.67860887],
#        [0.870804  , 0.129196  ],
#        [0.08537332, 0.91462668],
#        [0.68695088, 0.31304912],
#        [0.88626962, 0.11373038],
#        [0.93906749, 0.06093251],
#        [0.92675158, 0.07324842],
#        [0.60371052, 0.39628948],
#        [0.34814825, 0.65185175],
#        [0.90711053, 0.09288947],
#        [0.9267076 , 0.0732924 ],
#        [0.65433169, 0.34566831],
#        [0.78754646, 0.21245354],
#        [0.49270042, 0.50729958],
#        [0.71087816, 0.28912184],
#        [0.56392718, 0.43607282],
#        [0.32547311, 0.67452689],
#        [0.91086389, 0.08913611],
#        [0.95065875, 0.04934125],
#        [0.44791447, 0.55208553],
#        [0.82920335, 0.17079665],
#        [0.82829179, 0.17170821],
#        [0.85878057, 0.14121943],
#        [0.95480158, 0.04519842],
#        [0.88327177, 0.11672823],
#        [0.55057111, 0.44942889],
#        [0.65937881, 0.34062119],
#        [0.37014069, 0.62985931],
#        [0.5257837 , 0.4742163 ],
#        [0.65979481, 0.34020519],
#        [0.59870784, 0.40129216],
#        [0.89645103, 0.10354897],
#        [0.1387791 , 0.8612209 ],
#        [0.2481562 , 0.7518438 ],
#        [0.06286693, 0.93713307],
#        [0.78442985, 0.21557015],
#        [0.931861  , 0.068139  ],
#        [0.08647753, 0.91352247],
#        [0.63132273, 0.36867727],
#        [0.0843788 , 0.9156212 ],
#        [0.23649138, 0.76350862],
#        [0.35290552, 0.64709448],
#        [0.76507606, 0.23492394],
#        [0.87053708, 0.12946292],
#        [0.41988009, 0.58011991],
#        [0.9182075 , 0.0817925 ],
#        [0.94977047, 0.05022953],
#        [0.10656162, 0.89343838],
#        [0.23929686, 0.76070314],
#        [0.93531128, 0.06468872],
#        [0.61211619, 0.38788381],
#        [0.11978416, 0.88021584],
#        [0.33245514, 0.66754486],
#        [0.71172001, 0.28827999],
#        [0.32810184, 0.67189816],
#        [0.63151241, 0.36848759],
#        [0.99026842, 0.00973158],
#        [0.85644767, 0.14355233],
#        [0.88708092, 0.11291908],
#        [0.85311121, 0.14688879],
#        [0.46124188, 0.53875812],
#        [0.47633069, 0.52366931],
#        [0.96813947, 0.03186053],
#        [0.87269544, 0.12730456],
#        [0.59481122, 0.40518878],
#        [0.66648246, 0.33351754],
#        [0.84741083, 0.15258917],
#        [0.93006045, 0.06993955],
#        [0.56648228, 0.43351772],
#        [0.87900639, 0.12099361],
#        [0.03141642, 0.96858358],
#        [0.86688289, 0.13311711],
#        [0.02793457, 0.97206543],
#        [0.33133842, 0.66866158],
#        [0.09513244, 0.90486756],
#        [0.64391314, 0.35608686],
#        [0.81245068, 0.18754932],
#        [0.59091428, 0.40908572],
#        [0.53715991, 0.46284009],
#        [0.33078132, 0.66921868],
#        [0.66641933, 0.33358067]])

# %% [markdown]
# Now for the last time, I’ll be looking at the head and tail of the dataset so that we can take any random set of features from both the head and tail of the data to test that if our model is good enough to give the right prediction.

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# Putting data points in the model will either return 0 or 1 i.e. person suffering from diabetes or not.

# %%
# Make a prediction for the 4th patient
patient_data = [[0, 137, 40, 35, 168, 43.1, 2.228, 33]]
first_prediction_probabilities = classifier.predict_proba(patient_data)

# Check if the probability of being diabetic is higher than a threshold (e.g., 0.5)
threshold = 0.5
if first_prediction_probabilities[0][1] > threshold:
    print(f'The patient is {first_prediction_probabilities[0][1]*100:.2f}% diabetic.')
else:
    print(f'The patient is {100 - first_prediction_probabilities[0][1]*100:.2f}% not diabetic.')
# Out:
# The patient is 90.98% diabetic.

# %%
# Make a prediction for the 763rd patient
second_patient_data = [[10, 101, 80, 48, 180, 32.9, 0.171, 12]]
second_prediction_probabilities = classifier.predict_proba(second_patient_data)

# Define the threshold for medical practices (you can adjust this as needed)
threshold = 0.7

# Check if the probability of being diabetic is higher than the threshold
if second_prediction_probabilities[0][1] > threshold:
    print(f'The patient is diabetic with a probability of {second_prediction_probabilities[0][1]*100:.2f}%')
else:
    print('The patient is not diabetic')
# Out:
# The patient is not diabetic

# %% [markdown]
# **Conclusion**
#
# After using all these patient records, we are able to build a machine learning model (SVM – best one) to accurately predict whether or not the patients in the dataset have diabetes or not along with that we were able to draw some insights from the data via data analysis and visualization.
